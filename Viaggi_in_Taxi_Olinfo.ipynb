# %% [markdown]
# <a href="https://colab.research.google.com/github/Mick4speed/Colab-File/blob/main/Viaggi_in_Taxi_Olinfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Viaggi in Taxi**
#
# ---

# %% [markdown]
# *N* visitatori di un museo sono in attessa di prendere un taxi, e sono divisi in comitive. Ciascuna comitiva è identificata da un proprio numero; i numeri identificativi dei gruppi sono numeri qualsiasi, non in qualche ordine particolare. La persona *i* appartiene al gruppo *G[i]*, le persone sono messe in fila in modo che le persone dello stesso gruppo siano tutte di seguito.

# %% [markdown]
# Siccome ogni comitiva vuole viaggiare su un solo taxi per non dividersi, e non vuole condividere il taxi con altre comitive, quanti taxi servono per accompagnare a casa tutti i visitatori?

# %% [markdown]
# # **Formato di input**

# %% [markdown]
# La prima riga del file di input contiene un intero *T*, il numero di casi di test. Seguono *T* casi di test, numerati da *1* a *T*. Ogni caso di test è preceduto da una riga vuota.

# %% [markdown]
# Ogni caso di test è composto come segue:
#
#
# *   una riga contenente l'intero *N*.
# *   una riga contenente gli *N* interi *G*

# %% [markdown]
# Esempio:

# %%
# %%writefile input.txt
# 2
#
# 3
# 2 2 1
#
# 7
# 2 2 3 3 3 4 4
# Out:
# Writing input.txt

# %% [markdown]
# Output:
#
#
# ```
# Case #1: 2
# Case #2: 3
# ```

# %% [markdown]
# # **Codice**

# %% [markdown]
# Traccia:

# %%
# %%writefile taxi_traccia.cpp
# // NOTA: si raccomanda di usare questo template anche se non lo si capisce completamente.
#
# #include <fstream>
# #include <iostream>
# #include <string>
# #include <vector>
#
# using namespace std;
#
# int main() {
#     // decommenta le due righe seguenti se vuoi leggere/scrivere da file
#     ifstream cin("input.txt");
#     //ofstream cout("output.txt");
#
#     int T;
#     cin >> T;
#     for (int test = 1; test <= T; ++test) {
#         int N;
#         cin >> N;
#
#         vector<int> G(N);
#         for (int i = 0; i < N; ++i)
#             cin >> G[i];
#
#         int ris = 0;
#
#
#         // INSERISCI IL TUO CODICE QUI
#
#
#         cout << "Case #" << test << ": ";
#         cout << ris << endl;
#     }
#
#     return 0;
# }
# Out:
# Overwriting taxi.cpp

# %% [markdown]
# Codice:

# %%
# %%writefile taxi.cpp
# // NOTA: si raccomanda di usare questo template anche se non lo si capisce completamente.
#
# #include <fstream>
# #include <iostream>
# #include <string>
# #include <vector>
#
# using namespace std;
#
# int main() {
#     // decommenta le due righe seguenti se vuoi leggere/scrivere da file
#     ifstream cin("input.txt");
#     //ofstream cout("output.txt");
#
#     int T;
#     cin >> T;
#     for (int test = 1; test <= T; ++test) {
#         int N;
#         cin >> N;
#
#         vector<int> G(N);
#         for (int i = 0; i < N; ++i)
#             cin >> G[i];
#
#         int ris = 1;
#
#         for(int i = 1; i<N; i++){
#           if(G[i]!=G[i-1]) ris++;
#         }
#
#
#         cout << "Case #" << test << ": ";
#         cout << ris << endl;
#     }
#
#     return 0;
# }
# Out:
# Overwriting taxi.cpp

# %%
# %%bash
# g++ taxi.cpp -o taxi.o
# ./taxi.o
# Out:
# Case #1: 1
# Case #2: 2
